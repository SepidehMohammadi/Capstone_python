# %%
import pandas as pd
import numpy as np
import os
import seaborn as sns

path = os.path.join('Resources', 'online_shoppers_intention.csv')

df = pd.read_csv(path)

# %%
oneclick_Adminstrative_users = df[df['Administrative'] == 1]

# %%
oneclick_Adminstrative_users_mean_Adminstrative_Duration = oneclick_Adminstrative_users['Administrative_Duration'].mean(axis = 0, skipna = True)

# %%
oneclick_Adminstrative_users
# Out:
#        Administrative  Administrative_Duration  Informational  \
# 7                   1                     0.00              0
# 29                  1                     6.00              1
# 40                  1                     9.00              0
# 162                 1                     9.50              0
# 170                 1                     0.00              0
# ...               ...                      ...            ...
# 12280               1                    73.75              0
# 12281               1                    88.00              3
# 12308               1                    19.00              0
# 12310               1                     5.00              0
# 12311               1                     0.00              2
#
#        Informational_Duration  ProductRelated  ProductRelated_Duration  \
# 7                    0.000000               0                 0.000000
# 29                   0.000000              45              1582.750000
# ...

# %%
oneclick_Adminstrative_users_mean_Adminstrative_Duration
# Out:
# 42.49809741591211

# %%
df['Administrative_Duration'].loc[ (df['Administrative_Duration'] == 0) & (df['Administrative'] == 1)] = oneclick_Adminstrative_users_mean_Adminstrative_Duration
# Out:
# /home/sepideh/.local/share/virtualenvs/Capstone_python-WWuw0U2X/lib/python3.7/site-packages/pandas/core/indexing.py:671: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)

# %%
df.head(20)
# Out:
#     Administrative  Administrative_Duration  Informational  \
# 0                0                 0.000000              0
# 1                0                 0.000000              0
# 2                0                 0.000000              0
# 3                0                 0.000000              0
# 4                0                 0.000000              0
# 5                0                 0.000000              0
# 6                0                 0.000000              0
# 7                1                42.498097              0
# 8                0                 0.000000              0
# 9                0                 0.000000              0
# 10               0                 0.000000              0
# 11               0                 0.000000              0
# 12               0                 0.000000              0
# 13               0                 0.000000              0
# 14               0                 0.000000              0
# ...

# %%
twoclick_Adminstrative_users = df[df['Administrative'] == 2]

# %%
twoclick_Adminstrative_users_mean_Adminstrative_Duration = twoclick_Adminstrative_users['Administrative_Duration'].mean(axis = 0, skipna = True)

# %%
df['Administrative_Duration'].loc[ (df['Administrative_Duration'] == 0) & (df['Administrative'] == 2)] = twoclick_Adminstrative_users_mean_Adminstrative_Duration
